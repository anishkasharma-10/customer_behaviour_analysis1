# %%
print("Hello Jupyter")
# Out:
# Hello Jupyter

# %%
import pandas as pd

df = pd.read_csv("customer_shopping_behaviour.csv")   # CSV file
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("customer_shopping_behaviour.csv")   # CSV file
#       4 df.head()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os
os.listdir()
# Out:
# ['.bash_history',
#  '.EasyOCR',
#  '.git',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.node_repl_history',
#  '.vscode',
#  '.vscode-shared',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'customer_shopping_behaviour.csv.xlsx',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.blf',
#  'NTUSER.DAT{3f18ceee-494d-11f1-b1ce-ac74b1ca1787}.TM.blf',
#  'NTUSER.DAT{3f18ceee-494d-11f1-b1ce-ac74b1ca1787}.TMContainer00000000000000000001.regtrans-ms',
# ...

# %%
import pandas as pd

df = pd.read_excel("customer_shopping_behaviour.csv.xlsx")
df.head()
# Out:
#    Customer ID  Age Gender Item purchage  Category  Puchrase amount  \
# 0            1   55   Male        blouse  Clothing               53
# 1            2   19   Male       sweater  Clothing               64
# 2            3   50   Male         jeans  Clothing               73
# 3            4   21   Male        sandal  Footwear               90
# 4            5   45   Male        blouse  Clothing               49
#
#      Location Size    Colour  Season  Review Rate Subscription Status  \
# 0    Kenlucky    L      Gray  Winter          3.1                 Yes
# 1       Maine    L    Maroon  Winter          3.1                 Yes
# 2    Massachu    S    Maroon  Spring          3.1                 Yes
# 3  Rhode Isla    M    Maroon  Spring          3.5                 Yes
# 4      Oregon    M  Turqoise  Spring          2.7                 Yes
#
#     Shpping type Discount applied Prmomocode Used  Previous purchages  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             20 non-null     int64
#  1   Age                     20 non-null     int64
#  2   Gender                  20 non-null     str
#  3   Item purchage           20 non-null     str
#  4   Category                20 non-null     str
#  5   Puchrase amount         20 non-null     int64
#  6   Location                20 non-null     str
#  7   Size                    20 non-null     str
#  8   Colour                  20 non-null     str
#  9   Season                  20 non-null     str
#  10  Review Rate             20 non-null     float64
#  11  Subscription Status     20 non-null     str
#  12  Shpping type            20 non-null     str
#  13  Discount applied        20 non-null     str
#  14  Prmomocode Used         20 non-null     str
# ...

# %%
df.describe(include='all')
# Out:
#         Customer ID        Age Gender Item purchage  Category  \
# count      20.00000  20.000000     20            20        20
# unique          NaN        NaN      2            13         4
# top             NaN        NaN   Male          coat  Clothing
# freq            NaN        NaN     19             3        12
# mean       10.50000  47.100000    NaN           NaN       NaN
# std         5.91608  16.325311    NaN           NaN       NaN
# min         1.00000  19.000000    NaN           NaN       NaN
# 25%         5.75000  29.250000    NaN           NaN       NaN
# 50%        10.50000  52.500000    NaN           NaN       NaN
# 75%        15.25000  61.500000    NaN           NaN       NaN
# max        20.00000  66.000000    NaN           NaN       NaN
#
#         Puchrase amount    Location Size Colour  Season  Review Rate  \
# count           20.0000          20   20     20      20    20.000000
# unique              NaN          17    4     15       4          NaN
# ...

# %%
df.isnull.().sum()
# Out:
#   Cell In[8], line 1
#     df.isnull.().sum()
#               ^
# SyntaxError: invalid syntax

# %%
df.isnumull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.isnumull().sum()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'isnumull'

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item purchage             0
# Category                  0
# Puchrase amount           0
# Location                  0
# Size                      0
# Colour                    0
# Season                    0
# Review Rate               0
# Subscription Status       0
# Shpping type              0
# Discount applied          0
# Prmomocode Used           0
# Previous purchages        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df['Review rate']=df.groupby('Category')'['Review Rate'].transform(lamba x: x.filna(x.medium())
# Out:
#   Cell In[11], line 1
#     df['Review rate']=df.groupby('Category')'['Review Rate'].transform(lamba x: x.filna(x.medium())
#                                                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df['Review Rate'] = df.groupby('Category')['Review Rate'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item purchage             0
# Category                  0
# Puchrase amount           0
# Location                  0
# Size                      0
# Colour                    0
# Season                    0
# Review Rate               0
# Subscription Status       0
# Shpping type              0
# Discount applied          0
# Prmomocode Used           0
# Previous purchages        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df=df.rename(columns={puchrase_amount':'puchrase_amount'})
# Out:
#   Cell In[19], line 3
#     df=df.rename(columns={puchrase_amount':'puchrase_amount'})
#                                                            ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchage', 'category',
#        'puchrase_amount', 'location', 'size', 'colour', 'season',
#        'review_rate', 'subscription_status', 'shpping_type',
#        'discount_applied', 'prmomocode_used', 'previous_purchages',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchage', 'category',
#        'puchrase_amount', 'location', 'size', 'colour', 'season',
#        'review_rate', 'subscription_status', 'shpping_type',
#        'discount_applied', 'prmomocode_used', 'previous_purchages',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchage', 'category',
#        'puchrase_amount', 'location', 'size', 'colour', 'season',
#        'review_rate', 'subscription_status', 'shpping_type',
#        'discount_applied', 'prmomocode_used', 'previous_purchages',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
df['puchrase_amount']
# Out:
# 0     53
# 1     64
# 2     73
# 3     90
# 4     49
# 5     20
# 6     85
# 7     34
# 8     97
# 9     31
# 10    34
# 11    68
# 12    72
# 13    51
# 14    53
# 15    81
# 16    36
# 17    38
# 18    48
# 19    90
# Name: puchrase_amount, dtype: int64

# %%
df.rename(columns={'puchrase_amount': 'purchase_amount'}, inplace=True)

# %%
df['purchase_amount']
# Out:
# 0     53
# 1     64
# 2     73
# 3     90
# 4     49
# 5     20
# 6     85
# 7     34
# 8     97
# 9     31
# 10    34
# 11    68
# 12    72
# 13    51
# 14    53
# 15    81
# 16    36
# 17    38
# 18    48
# 19    90
# Name: purchase_amount, dtype: int64

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchage', 'category',
#        'purchase_amount', 'location', 'size', 'colour', 'season',
#        'review_rate', 'subscription_status', 'shpping_type',
#        'discount_applied', 'prmomocode_used', 'previous_purchages',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
#create a column age_group
labels=['Young Adult','Adult','Middle-Age','Senior']
df['age_group']=pd.qcut(df['age'],q=4,labels=labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   55   Middle-Age
# 1   19  Young Adult
# 2   50        Adult
# 3   21  Young Adult
# 4   45        Adult
# 5   46        Adult
# 6   63       Senior
# 7   27  Young Adult
# 8   26  Young Adult
# 9   57   Middle-Age

# %%
#create column purchase_frequency_days

frequency_mapping = {
    'Daily': 1,
    'Weekly': 7,
    'Bi-Weekly': 14,
    'Monthly': 30,
    'Quarterly': 90,
    'Annually': 365
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['frequency_of_purchases']].head(10)
# Out:
#   frequency_of_purchases
# 0            Fortnightly
# 1            Fortnightly
# 2                 Weekly
# 3                 Weekly
# 4               Annually
# 5                 Weekly
# 6              Quarterly
# 7                 Weekly
# 8               Annually
# 9              Quarterly

# %%
frequency_mapping = {
    'Daily': 1,
    'Weekly': 7,
    'Bi-Weekly': 14,
    'Monthly': 30,
    'Quarterly': 90,
    'Annually': 365
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['frequency_of_purchases','purchase_frequency_days']].head(10)
# Out:
#   frequency_of_purchases  purchase_frequency_days
# 0            Fortnightly                      NaN
# 1            Fortnightly                      NaN
# 2                 Weekly                      7.0
# 3                 Weekly                      7.0
# 4               Annually                    365.0
# 5                 Weekly                      7.0
# 6              Quarterly                     90.0
# 7                 Weekly                      7.0
# 8               Annually                    365.0
# 9              Quarterly                     90.0

# %%
df[['discount_applied','prmomocode_used']].head(10)
# Out:
#   discount_applied prmomocode_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied'] == df['prmomocode_used']).all()
# Out:
# np.True_

# %%
df = df.drop('prmomocode_used', axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchage', 'category',
#        'purchase_amount', 'location', 'size', 'colour', 'season',
#        'review_rate', 'subscription_status', 'shpping_type',
#        'discount_applied', 'previous_purchages', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='str')

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import sqlalchemy

print("All good ✅")
# Out:
# All good ✅

# %%
# Step 1: Connect to PostgreSQL

from sqlalchemy import create_engine

# Replace with your details
username = "postgres"          # default user
password = "anishka"          # your PostgreSQL password
host = "localhost"             # running locally
port = "5432"                  # default port
database = "customer_behaviour" # your database name

# Create connection
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")


# Step 2: Load DataFrame into PostgreSQL

table_name = "customer"   # table name

df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}' ✅")
# Out:
# Data successfully loaded into table 'customer' in database 'customer_behaviour' ✅

# %%
pd.read_sql("SELECT * FROM customer LIMIT 5", engine)
# Out:
# Empty DataFrame
# Columns: [name, age]
# Index: []

# %%
import pandas as pd

pd.read_sql("SELECT * FROM customer LIMIT 5", engine)
# Out:
# Empty DataFrame
# Columns: [name, age]
# Index: []

# %%
from sqlalchemy import text

with engine.connect() as conn:
    conn.execute(text("DROP TABLE IF EXISTS customer"))
    conn.commit()

print("Table deleted successfully")
# Out:
# Table deleted successfully

# %%
df.to_sql("customer", engine, if_exists="replace", index=False)

print("Data loaded successfully")
# Out:
# Data loaded successfully

# %%
import pandas as pd

pd.read_sql("SELECT * FROM customer LIMIT 5", engine)
# Out:
#       name  age
# 0  Anishka   20
# 1    Rahul   22
# 2    Priya   21

# %%
print(df.shape)
print(df.columns)
# Out:
# (3, 2)
# Index(['name', 'age'], dtype='str')

# %%
pd.read_sql("SELECT current_database();", engine)
# Out:
#      current_database
# 0  customer_behaviour

# %%
pd.read_sql("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema = 'public';
""", engine)
# Out:
#   table_name
# 0   customer

# %%
pd.read_sql("""
SELECT column_name
FROM information_schema.columns
WHERE table_name = 'customer';
""", engine)
# Out:
#   column_name
# 0         age
# 1        name

# %%
df.to_sql("customer_new", engine, if_exists="replace", index=False)
# Out:
# 3

# %%
pd.read_sql("""
SELECT column_name
FROM information_schema.columns
WHERE table_name='customer_new';
""", engine)
# Out:
#   column_name
# 0         age
# 1        name

# %%
from sqlalchemy import text

with engine.connect() as conn:
    conn.execute(text("DROP TABLE IF EXISTS customer"))
    conn.commit()

# %%
df.to_sql("customer", engine, if_exists="replace", index=False)
# Out:
# 3

# %%
import pandas as pd

df = pd.read_excel("customer_shopping_behaviour.csv.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("customer_shopping_behaviour.csv.xlsx")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.bash_history', '.EasyOCR', '.git', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.node_repl_history', '.vscode', '.vscode-shared', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'customer_shopping_behaviour_analysis.ipynb', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.0.regtrans-ms', 'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.1.regtrans-ms', 'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.2.regtrans-ms', 'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.blf', 'NTUSER.DAT{3f18ceee-494d-11f1-b1ce-ac74b1ca1787}.TM.blf', 'NTUSER.DAT{3f18ceee-494d-11f1-b1ce-ac74b1ca1787}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{3f18ceee-494d-11f1-b1ce-ac74b1ca1787}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHoo
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\WELCOME

# %%
import os

for root, dirs, files in os.walk("Downloads"):
    for file in files:
        if "customer" in file.lower():
            print(os.path.join(root, file))

# %%
for root, dirs, files in os.walk("Desktop"):
    for file in files:
        if "customer" in file.lower():
            print(os.path.join(root, file))
# Out:
# Desktop\customer_shopping_behaviour.csv
# Desktop\customer_shopping_behaviour.csv.xlsx
# Desktop\expense-tracker\expense-tracker\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\expense-tracker\expense-tracker\node_modules\csso\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\expense-tracker\expense-tracker\node_modules\postcss-svgo\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\zerodha project app anishka\frontend\frontend\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\zerodha project app anishka\frontend\frontend\node_modules\csso\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\zerodha project app anishka\frontend\frontend\node_modules\postcss-svgo\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\zerodha project app anishka\frontend\node_modules\css-tree\lib\utils\createCustomError.js
# ...

# %%
import pandas as pd

df = pd.read_csv("customer_shopping_behaviour.csv")   # CSV file
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("customer_shopping_behaviour.csv")   # CSV file
#       4 df.head()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os
os.listdir()
# Out:
# ['.bash_history',
#  '.EasyOCR',
#  '.git',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.node_repl_history',
#  '.vscode',
#  '.vscode-shared',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'customer_shopping_behaviour_analysis.ipynb',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{3f18ceed-494d-11f1-b1ce-ac74b1ca1787}.TxR.blf',
#  'NTUSER.DAT{3f18ceee-494d-11f1-b1ce-ac74b1ca1787}.TM.blf',
#  'NTUSER.DAT{3f18ceee-494d-11f1-b1ce-ac74b1ca1787}.TMContainer00000000000000000001.regtrans-ms',
# ...

# %%
import pandas as pd

df = pd.read_excel("customer_shopping_behaviour.csv.xlsx")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("customer_shopping_behaviour.csv.xlsx")
#       4 df.head()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\WELCOME

# %%
import os

for root, dirs, files in os.walk("Downloads"):
    for file in files:
        if "customer" in file.lower():
            print(os.path.join(root, file))

# %%
for root, dirs, files in os.walk("Desktop"):
    for file in files:
        if "customer" in file.lower():
            print(os.path.join(root, file))
# Out:
# Desktop\customer_shopping_behaviour.csv
# Desktop\customer_shopping_behaviour.csv.xlsx
# Desktop\expense-tracker\expense-tracker\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\expense-tracker\expense-tracker\node_modules\csso\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\expense-tracker\expense-tracker\node_modules\postcss-svgo\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\zerodha project app anishka\frontend\frontend\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\zerodha project app anishka\frontend\frontend\node_modules\csso\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\zerodha project app anishka\frontend\frontend\node_modules\postcss-svgo\node_modules\css-tree\lib\utils\createCustomError.js
# Desktop\zerodha project app anishka\frontend\node_modules\css-tree\lib\utils\createCustomError.js
# ...

# %%
df = pd.read_csv(r"Desktop\customer_shopping_behaviour.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item purchage  Category  Puchrase amount  \
# 0            1   55   Male        blouse  Clothing               53
# 1            2   19   Male       sweater  Clothing               64
# 2            3   50   Male         jeans  Clothing               73
# 3            4   21   Male        sandal  Footwear               90
# 4            5   45   Male        blouse  Clothing               49
#
#      Location Size    Colour  Season  Review Rate Subscription Status  \
# 0    Kenlucky    L      Gray  Winter          3.1                 Yes
# 1       Maine    L    Maroon  Winter          3.1                 Yes
# 2    Massachu    S    Maroon  Spring          3.1                 Yes
# 3  Rhode Isla    M    Maroon  Spring          3.5                 Yes
# 4      Oregon    M  Turqoise  Spring          2.7                 Yes
#
#     Shpping type Discount applied Prmomocode Used  Previous purchages  \
# ...

# %%
df = pd.read_csv(r"Desktop\customer_shopping_behaviour.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item purchage  Category  Puchrase amount  \
# 0            1   55   Male        blouse  Clothing               53
# 1            2   19   Male       sweater  Clothing               64
# 2            3   50   Male         jeans  Clothing               73
# 3            4   21   Male        sandal  Footwear               90
# 4            5   45   Male        blouse  Clothing               49
#
#      Location Size    Colour  Season  Review Rate Subscription Status  \
# 0    Kenlucky    L      Gray  Winter          3.1                 Yes
# 1       Maine    L    Maroon  Winter          3.1                 Yes
# 2    Massachu    S    Maroon  Spring          3.1                 Yes
# 3  Rhode Isla    M    Maroon  Spring          3.5                 Yes
# 4      Oregon    M  Turqoise  Spring          2.7                 Yes
#
#     Shpping type Discount applied Prmomocode Used  Previous purchages  \
# ...

# %%
pd.read_sql("SELECT current_database();", engine)
# Out:
#      current_database
# 0  customer_behaviour

# %%
pd.read_sql("SELECT * FROM customer LIMIT 5;", engine)
# Out:
#       name  age
# 0  Anishka   20
# 1    Rahul   22
# 2    Priya   21

# %%
df = pd.read_csv(r"Desktop\customer_shopping_behaviour.csv")

df.head()
# Out:
#    Customer ID  Age Gender Item purchage  Category  Puchrase amount  \
# 0            1   55   Male        blouse  Clothing               53
# 1            2   19   Male       sweater  Clothing               64
# 2            3   50   Male         jeans  Clothing               73
# 3            4   21   Male        sandal  Footwear               90
# 4            5   45   Male        blouse  Clothing               49
#
#      Location Size    Colour  Season  Review Rate Subscription Status  \
# 0    Kenlucky    L      Gray  Winter          3.1                 Yes
# 1       Maine    L    Maroon  Winter          3.1                 Yes
# 2    Massachu    S    Maroon  Spring          3.1                 Yes
# 3  Rhode Isla    M    Maroon  Spring          3.5                 Yes
# 4      Oregon    M  Turqoise  Spring          2.7                 Yes
#
#     Shpping type Discount applied Prmomocode Used  Previous purchages  \
# ...

# %%
print(df.columns)
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item purchage', 'Category',
#        'Puchrase amount', 'Location', 'Size', 'Colour', 'Season',
#        'Review Rate', 'Subscription Status', 'Shpping type',
#        'Discount applied', 'Prmomocode Used', 'Previous purchages',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='str')

# %%
from sqlalchemy import text

with engine.connect() as conn:
    conn.execute(text("DROP TABLE IF EXISTS customer"))
    conn.commit()

# %%
df.to_sql("customer", engine, if_exists="replace", index=False)
# Out:
# 20

# %%
pd.read_sql("SELECT * FROM customer LIMIT 5", engine)
# Out:
#    Customer ID  Age Gender Item purchage  Category  Puchrase amount  \
# 0            1   55   Male        blouse  Clothing               53
# 1            2   19   Male       sweater  Clothing               64
# 2            3   50   Male         jeans  Clothing               73
# 3            4   21   Male        sandal  Footwear               90
# 4            5   45   Male        blouse  Clothing               49
#
#      Location Size    Colour  Season  Review Rate Subscription Status  \
# 0    Kenlucky    L      Gray  Winter          3.1                 Yes
# 1       Maine    L    Maroon  Winter          3.1                 Yes
# 2    Massachu    S    Maroon  Spring          3.1                 Yes
# 3  Rhode Isla    M    Maroon  Spring          3.5                 Yes
# 4      Oregon    M  Turqoise  Spring          2.7                 Yes
#
#     Shpping type Discount applied Prmomocode Used  Previous purchages  \
# ...

# %%
from sqlalchemy import text

with engine.connect() as conn:
    conn.execute(text("DROP TABLE IF EXISTS customer"))
    conn.commit()

print("Old table deleted")
# Out:
# Old table deleted

# %%
df.to_sql("customer", engine, if_exists="replace", index=False)

print("Shopping data uploaded")
# Out:
# Shopping data uploaded

# %%
pd.read_sql("SELECT * FROM customer LIMIT 5", engine)
# Out:
#    Customer ID  Age Gender Item purchage  Category  Puchrase amount  \
# 0            1   55   Male        blouse  Clothing               53
# 1            2   19   Male       sweater  Clothing               64
# 2            3   50   Male         jeans  Clothing               73
# 3            4   21   Male        sandal  Footwear               90
# 4            5   45   Male        blouse  Clothing               49
#
#      Location Size    Colour  Season  Review Rate Subscription Status  \
# 0    Kenlucky    L      Gray  Winter          3.1                 Yes
# 1       Maine    L    Maroon  Winter          3.1                 Yes
# 2    Massachu    S    Maroon  Spring          3.1                 Yes
# 3  Rhode Isla    M    Maroon  Spring          3.5                 Yes
# 4      Oregon    M  Turqoise  Spring          2.7                 Yes
#
#     Shpping type Discount applied Prmomocode Used  Previous purchages  \
# ...

# %%
pip install pyodbc sqlalachemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sqlalachemy (from versions: none)
# ERROR: No matching distribution found for sqlalachemy

# %%
pip install pyodbc sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pyodbc-5.3.0-cp314-cp314-win_amd64.whl.metadata (2.8 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc
import sqlalchemy

print("Libraries Installed Successfully")
# Out:
# Libraries Installed Successfully

# %%
from sqlalchemy import create_engine

server = "localhost"
database = "customer_behaviour"

engine = create_engine(
    f"mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

print("Connected Successfully")
# Out:
# Connected Successfully

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
pip install pyodbc sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
print(os.path.expanduser("~"))
# Out:
# C:\Users\WELCOME

# %%
df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")

print(df.head())
# Out:
#    Customer ID  Age Gender Item purchage  Category  Puchrase amount  \
# 0            1   55   Male        blouse  Clothing               53
# 1            2   19   Male       sweater  Clothing               64
# 2            3   50   Male         jeans  Clothing               73
# 3            4   21   Male        sandal  Footwear               90
# 4            5   45   Male        blouse  Clothing               49
#
#      Location Size    Colour  Season  Review Rate Subscription Status  \
# 0    Kenlucky    L      Gray  Winter          3.1                 Yes
# 1       Maine    L    Maroon  Winter          3.1                 Yes
# 2    Massachu    S    Maroon  Spring          3.1                 Yes
# 3  Rhode Isla    M    Maroon  Spring          3.5                 Yes
# 4      Oregon    M  Turqoise  Spring          2.7                 Yes
#
#     Shpping type Discount applied Prmomocode Used  Previous purchages  \
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# CSV already loaded (tumne bola aa gaya)
df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")

# MySQL connection
username = "root"
password = "anishka"
host = "localhost"
port = "3306"
database = "mydatabase"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

# Table name
table_name = "mytable"

# Upload to MySQL
df.to_sql(table_name, engine, if_exists="replace", index=False)

# Verify
result = pd.read_sql("SELECT * FROM mytable LIMIT 5", engine)
print(result)

# %%
pip install pyodbc sqlalchemy pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load CSV
df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")

# MS SQL Server (Windows Authentication)
server = "localhost"
database = "mydatabase"

engine = create_engine(
    "mssql+pyodbc://@localhost/mydatabase?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# Table name
table_name = "mytable"

# Upload data
df.to_sql(table_name, engine, if_exists="replace", index=False)

# Verify
result = pd.read_sql(f"SELECT TOP 5 * FROM {table_name}", engine)
print(result)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
print("Jupyter working")
# Out:
# Jupyter working

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item purchage  Category  Puchrase amount  \
# 0            1   55   Male        blouse  Clothing               53
# 1            2   19   Male       sweater  Clothing               64
# 2            3   50   Male         jeans  Clothing               73
# 3            4   21   Male        sandal  Footwear               90
# 4            5   45   Male        blouse  Clothing               49
#
#      Location Size    Colour  Season  Review Rate Subscription Status  \
# 0    Kenlucky    L      Gray  Winter          3.1                 Yes
# 1       Maine    L    Maroon  Winter          3.1                 Yes
# 2    Massachu    S    Maroon  Spring          3.1                 Yes
# 3  Rhode Isla    M    Maroon  Spring          3.5                 Yes
# 4      Oregon    M  Turqoise  Spring          2.7                 Yes
#
#     Shpping type Discount applied Prmomocode Used  Previous purchages  \
# ...

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)', 'ODBC Driver 18 for SQL Server']

# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")

engine = create_engine(
    "mssql+pyodbc://@localhost/mydatabase?driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&Encrypt=no"
)

df.to_sql("mytable", engine, if_exists="replace", index=False)

print("DATA UPLOADED SUCCESSFULLY")

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")

engine = create_engine(
    "mssql+pyodbc://DESKTOP-O3UFEPG\\SQLEXPRESS/mydatabase"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes"
    "&Encrypt=no"
)

df.to_sql("mytable", engine, if_exists="replace", index=False)

print("DATA UPLOADED SUCCESSFULLY")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
CREATE DATABASE mydatabase;
# Out:
#   Cell In[2], line 1
#     CREATE DATABASE mydatabase;
#            ^
# SyntaxError: invalid syntax

# %%
"DESKTOP-O3UFEPG\\SQLEXPRESS"
# Out:
# 'DESKTOP-O3UFEPG\\SQLEXPRESS'

# %%
from sqlalchemy import create_engine
import pandas as pd

df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")

engine = create_engine(
    "mssql+pyodbc://DESKTOP-O3UFEPG\\SQLEXPRESS/mydatabase"
    "?driver=ODBC+Driver+18+for+SQL+Server"
    "&trusted_connection=yes"
    "&Encrypt=no"
)

df.to_sql("mytable", engine, if_exists="replace", index=False)

print("DATA UPLOADED SUCCESSFULLY")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)   3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
#     441 """Return a DBAPI connection from the pool.
#     442
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

df = pd.read_csv(r"C:\Users\WELCOME\Desktop\customer_shopping_behaviour.csv")

engine = create_engine(
    "mssql+pyodbc://DESKTOP-O3UFEPG\\SQLEXPRESS/mydatabase?driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&Encrypt=no"
)

df.to_sql("mytable", engine, if_exists="replace", index=False)

print("DATA UPLOADED SUCCESSFULLY")
# Out:
# DATA UPLOADED SUCCESSFULLY
